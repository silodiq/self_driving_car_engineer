# %%
from tensorflow.examples.tutorials.mnist import input_data
import tensorflow as tf
import numpy as np
from helper import batches  # Helper function created in Mini-batching section


def print_epoch_stats(epoch_i, sess, last_features, last_labels):
    """
    Print cost and validation accuracy of an epoch
    """
    current_cost = sess.run(
        cost,
        feed_dict={features: last_features, labels: last_labels})
    valid_accuracy = sess.run(
        accuracy,
        feed_dict={features: valid_features, labels: valid_labels})
    print('Epoch: {:<4} - Cost: {:<8.3} Valid Accuracy: {:<5.3}'.format(
        epoch_i,
        current_cost,
        valid_accuracy))

n_input = 784  # MNIST data input (img shape: 28*28)
n_classes = 10  # MNIST total classes (0-9 digits)

# Import MNIST data
mnist = input_data.read_data_sets('/datasets/ud730/mnist', one_hot=True)

# The features are already scaled and the data is shuffled
train_features = mnist.train.images
valid_features = mnist.validation.images
test_features = mnist.test.images

train_labels = mnist.train.labels.astype(np.float32)
valid_labels = mnist.validation.labels.astype(np.float32)
test_labels = mnist.test.labels.astype(np.float32)

# Features and Labels
features = tf.placeholder(tf.float32, [None, n_input])
labels = tf.placeholder(tf.float32, [None, n_classes])

# Weights & bias
weights = tf.Variable(tf.random_normal([n_input, n_classes]))
bias = tf.Variable(tf.random_normal([n_classes]))

# Logits - xW + b
logits = tf.add(tf.matmul(features, weights), bias)

# Define loss and optimizer
learning_rate = tf.placeholder(tf.float32)
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=labels))
optimizer = tf.train.GradientDescentOptimizer(learning_rate=learning_rate).minimize(cost)

# Calculate accuracy
correct_prediction = tf.equal(tf.argmax(logits, 1), tf.argmax(labels, 1))
accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))

init = tf.global_variables_initializer()

batch_size = 128
epochs = 120
learn_rate = 0.001

train_batches = batches(batch_size, train_features, train_labels)

with tf.Session() as sess:
    sess.run(init)

    # Training cycle
    for epoch_i in range(epochs):

        # Loop over all batches
        for batch_features, batch_labels in train_batches:
            train_feed_dict = {
                features: batch_features,
                labels: batch_labels,
                learning_rate: learn_rate}
            sess.run(optimizer, feed_dict=train_feed_dict)

        # Print cost and validation accuracy of an epoch
        print_epoch_stats(epoch_i, sess, batch_features, batch_labels)

    # Calculate accuracy for test dataset
    test_accuracy = sess.run(
        accuracy,
        feed_dict={features: test_features, labels: test_labels})
   
    

print('Test Accuracy: {}'.format(test_accuracy))
# Out:
# Extracting /datasets/ud730/mnist\train-images-idx3-ubyte.gz
# Extracting /datasets/ud730/mnist\train-labels-idx1-ubyte.gz
# Extracting /datasets/ud730/mnist\t10k-images-idx3-ubyte.gz
# Extracting /datasets/ud730/mnist\t10k-labels-idx1-ubyte.gz
# Epoch: 0    - Cost: 11.0     Valid Accuracy: 0.0912
# Epoch: 1    - Cost: 9.91     Valid Accuracy: 0.1
# Epoch: 2    - Cost: 9.12     Valid Accuracy: 0.107
# Epoch: 3    - Cost: 8.5      Valid Accuracy: 0.125
# Epoch: 4    - Cost: 7.99     Valid Accuracy: 0.142
# Epoch: 5    - Cost: 7.56     Valid Accuracy: 0.16
# Epoch: 6    - Cost: 7.17     Valid Accuracy: 0.18
# Epoch: 7    - Cost: 6.81     Valid Accuracy: 0.202
# Epoch: 8    - Cost: 6.49     Valid Accuracy: 0.225
# Epoch: 9    - Cost: 6.19     Valid Accuracy: 0.242
# Epoch: 10   - Cost: 5.92     Valid Accuracy: 0.257
# Epoch: 11   - Cost: 5.66     Valid Accuracy: 0.275
# Epoch: 12   - Cost: 5.43     Valid Accuracy: 0.291
# Epoch: 13   - Cost: 5.21     Valid Accuracy: 0.307
# Epoch: 14   - Cost: 5.02     Valid Accuracy: 0.322
# Epoch: 15   - Cost: 4.83     Valid Accuracy: 0.337
# Epoch: 16   - Cost: 4.67     Valid Accuracy: 0.353
# Epoch: 17   - Cost: 4.51     Valid Accuracy: 0.367
# Epoch: 18   - Cost: 4.37     Valid Accuracy: 0.379
# Epoch: 19   - Cost: 4.24     Valid Accuracy: 0.392
# Epoch: 20   - Cost: 4.12     Valid Accuracy: 0.403
# Epoch: 21   - Cost: 4.0      Valid Accuracy: 0.414
# Epoch: 22   - Cost: 3.9      Valid Accuracy: 0.426
# Epoch: 23   - Cost: 3.8      Valid Accuracy: 0.436
# Epoch: 24   - Cost: 3.7      Valid Accuracy: 0.45
# Epoch: 25   - Cost: 3.61     Valid Accuracy: 0.46
# Epoch: 26   - Cost: 3.53     Valid Accuracy: 0.471
# Epoch: 27   - Cost: 3.45     Valid Accuracy: 0.48
# Epoch: 28   - Cost: 3.38     Valid Accuracy: 0.489
# Epoch: 29   - Cost: 3.3      Valid Accuracy: 0.499
# Epoch: 30   - Cost: 3.24     Valid Accuracy: 0.506
# Epoch: 31   - Cost: 3.17     Valid Accuracy: 0.511
# Epoch: 32   - Cost: 3.11     Valid Accuracy: 0.519
# Epoch: 33   - Cost: 3.05     Valid Accuracy: 0.525
# Epoch: 34   - Cost: 2.99     Valid Accuracy: 0.532
# Epoch: 35   - Cost: 2.94     Valid Accuracy: 0.537
# Epoch: 36   - Cost: 2.89     Valid Accuracy: 0.543
# Epoch: 37   - Cost: 2.84     Valid Accuracy: 0.548
# Epoch: 38   - Cost: 2.79     Valid Accuracy: 0.554
# Epoch: 39   - Cost: 2.75     Valid Accuracy: 0.56
# Epoch: 40   - Cost: 2.71     Valid Accuracy: 0.565
# Epoch: 41   - Cost: 2.66     Valid Accuracy: 0.57
# Epoch: 42   - Cost: 2.62     Valid Accuracy: 0.575
# Epoch: 43   - Cost: 2.59     Valid Accuracy: 0.579
# Epoch: 44   - Cost: 2.55     Valid Accuracy: 0.582
# Epoch: 45   - Cost: 2.51     Valid Accuracy: 0.586
# Epoch: 46   - Cost: 2.48     Valid Accuracy: 0.59
# Epoch: 47   - Cost: 2.45     Valid Accuracy: 0.594
# Epoch: 48   - Cost: 2.42     Valid Accuracy: 0.598
# Epoch: 49   - Cost: 2.39     Valid Accuracy: 0.601
# Epoch: 50   - Cost: 2.36     Valid Accuracy: 0.606
# Epoch: 51   - Cost: 2.33     Valid Accuracy: 0.609
# Epoch: 52   - Cost: 2.3      Valid Accuracy: 0.613
# Epoch: 53   - Cost: 2.27     Valid Accuracy: 0.616
# Epoch: 54   - Cost: 2.25     Valid Accuracy: 0.618
# Epoch: 55   - Cost: 2.22     Valid Accuracy: 0.621
# Epoch: 56   - Cost: 2.2      Valid Accuracy: 0.624
# Epoch: 57   - Cost: 2.18     Valid Accuracy: 0.628
# Epoch: 58   - Cost: 2.15     Valid Accuracy: 0.631
# Epoch: 59   - Cost: 2.13     Valid Accuracy: 0.633
# Epoch: 60   - Cost: 2.11     Valid Accuracy: 0.635
# Epoch: 61   - Cost: 2.09     Valid Accuracy: 0.636
# Epoch: 62   - Cost: 2.07     Valid Accuracy: 0.639
# Epoch: 63   - Cost: 2.05     Valid Accuracy: 0.641
# Epoch: 64   - Cost: 2.03     Valid Accuracy: 0.643
# Epoch: 65   - Cost: 2.01     Valid Accuracy: 0.646
# Epoch: 66   - Cost: 1.99     Valid Accuracy: 0.649
# Epoch: 67   - Cost: 1.97     Valid Accuracy: 0.652
# Epoch: 68   - Cost: 1.96     Valid Accuracy: 0.654
# Epoch: 69   - Cost: 1.94     Valid Accuracy: 0.658
# Epoch: 70   - Cost: 1.92     Valid Accuracy: 0.661
# Epoch: 71   - Cost: 1.91     Valid Accuracy: 0.662
# Epoch: 72   - Cost: 1.89     Valid Accuracy: 0.664
# Epoch: 73   - Cost: 1.87     Valid Accuracy: 0.667
# Epoch: 74   - Cost: 1.86     Valid Accuracy: 0.671
# Epoch: 75   - Cost: 1.84     Valid Accuracy: 0.673
# Epoch: 76   - Cost: 1.83     Valid Accuracy: 0.675
# Epoch: 77   - Cost: 1.81     Valid Accuracy: 0.676
# Epoch: 78   - Cost: 1.8      Valid Accuracy: 0.678
# Epoch: 79   - Cost: 1.79     Valid Accuracy: 0.681
# Epoch: 80   - Cost: 1.77     Valid Accuracy: 0.684
# Epoch: 81   - Cost: 1.76     Valid Accuracy: 0.685
# Epoch: 82   - Cost: 1.75     Valid Accuracy: 0.688
# Epoch: 83   - Cost: 1.74     Valid Accuracy: 0.689
# Epoch: 84   - Cost: 1.72     Valid Accuracy: 0.691
# Epoch: 85   - Cost: 1.71     Valid Accuracy: 0.693
# Epoch: 86   - Cost: 1.7      Valid Accuracy: 0.695
# Epoch: 87   - Cost: 1.69     Valid Accuracy: 0.697
# Epoch: 88   - Cost: 1.68     Valid Accuracy: 0.698
# Epoch: 89   - Cost: 1.66     Valid Accuracy: 0.7
# Epoch: 90   - Cost: 1.65     Valid Accuracy: 0.701
# Epoch: 91   - Cost: 1.64     Valid Accuracy: 0.702
# Epoch: 92   - Cost: 1.63     Valid Accuracy: 0.704
# Epoch: 93   - Cost: 1.62     Valid Accuracy: 0.706
# Epoch: 94   - Cost: 1.61     Valid Accuracy: 0.708
# Epoch: 95   - Cost: 1.6      Valid Accuracy: 0.709
# Epoch: 96   - Cost: 1.59     Valid Accuracy: 0.71
# Epoch: 97   - Cost: 1.58     Valid Accuracy: 0.713
# Epoch: 98   - Cost: 1.57     Valid Accuracy: 0.714
# Epoch: 99   - Cost: 1.56     Valid Accuracy: 0.716
# Epoch: 100  - Cost: 1.55     Valid Accuracy: 0.716
# Epoch: 101  - Cost: 1.54     Valid Accuracy: 0.718
# Epoch: 102  - Cost: 1.54     Valid Accuracy: 0.72
# Epoch: 103  - Cost: 1.53     Valid Accuracy: 0.721
# Epoch: 104  - Cost: 1.52     Valid Accuracy: 0.721
# Epoch: 105  - Cost: 1.51     Valid Accuracy: 0.723
# Epoch: 106  - Cost: 1.5      Valid Accuracy: 0.724
# Epoch: 107  - Cost: 1.49     Valid Accuracy: 0.726
# Epoch: 108  - Cost: 1.48     Valid Accuracy: 0.727
# Epoch: 109  - Cost: 1.48     Valid Accuracy: 0.729
# Epoch: 110  - Cost: 1.47     Valid Accuracy: 0.73
# Epoch: 111  - Cost: 1.46     Valid Accuracy: 0.731
# Epoch: 112  - Cost: 1.45     Valid Accuracy: 0.732
# Epoch: 113  - Cost: 1.45     Valid Accuracy: 0.733
# Epoch: 114  - Cost: 1.44     Valid Accuracy: 0.734
# Epoch: 115  - Cost: 1.43     Valid Accuracy: 0.735
# Epoch: 116  - Cost: 1.42     Valid Accuracy: 0.736
# Epoch: 117  - Cost: 1.42     Valid Accuracy: 0.737
# Epoch: 118  - Cost: 1.41     Valid Accuracy: 0.738
# Epoch: 119  - Cost: 1.4      Valid Accuracy: 0.74
# Test Accuracy: [ True False  True ...,  True False  True]
