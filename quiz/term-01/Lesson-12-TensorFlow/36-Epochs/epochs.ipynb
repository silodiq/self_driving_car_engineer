# %%
from tensorflow.examples.tutorials.mnist import input_data
import tensorflow as tf
import numpy as np
from helper import batches  # Helper function created in Mini-batching section


def print_epoch_stats(epoch_i, sess, last_features, last_labels):
    """
    Print cost and validation accuracy of an epoch
    """
    current_cost = sess.run(
        cost,
        feed_dict={features: last_features, labels: last_labels})
    valid_accuracy = sess.run(
        accuracy,
        feed_dict={features: valid_features, labels: valid_labels})
    print('Epoch: {:<4} - Cost: {:<8.3} Valid Accuracy: {:<5.3}'.format(
        epoch_i,
        current_cost,
        valid_accuracy))

n_input = 784  # MNIST data input (img shape: 28*28)
n_classes = 10  # MNIST total classes (0-9 digits)

# Import MNIST data
mnist = input_data.read_data_sets('/datasets/ud730/mnist', one_hot=True)

# The features are already scaled and the data is shuffled
train_features = mnist.train.images
valid_features = mnist.validation.images
test_features = mnist.test.images

train_labels = mnist.train.labels.astype(np.float32)
valid_labels = mnist.validation.labels.astype(np.float32)
test_labels = mnist.test.labels.astype(np.float32)

# Features and Labels
features = tf.placeholder(tf.float32, [None, n_input])
labels = tf.placeholder(tf.float32, [None, n_classes])

# Weights & bias
weights = tf.Variable(tf.random_normal([n_input, n_classes]))
bias = tf.Variable(tf.random_normal([n_classes]))

# Logits - xW + b
logits = tf.add(tf.matmul(features, weights), bias)

# Define loss and optimizer
learning_rate = tf.placeholder(tf.float32)
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=labels))
optimizer = tf.train.GradientDescentOptimizer(learning_rate=learning_rate).minimize(cost)

# Calculate accuracy
correct_prediction = tf.equal(tf.argmax(logits, 1), tf.argmax(labels, 1))
accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))

init = tf.global_variables_initializer()

batch_size = 128
epochs = 200
learn_rate = 0.0001

train_batches = batches(batch_size, train_features, train_labels)

with tf.Session() as sess:
    sess.run(init)

    # Training cycle
    for epoch_i in range(epochs):

        # Loop over all batches
        for batch_features, batch_labels in train_batches:
            train_feed_dict = {
                features: batch_features,
                labels: batch_labels,
                learning_rate: learn_rate}
            sess.run(optimizer, feed_dict=train_feed_dict)

        # Print cost and validation accuracy of an epoch
        print_epoch_stats(epoch_i, sess, batch_features, batch_labels)

    # Calculate accuracy for test dataset
    test_accuracy = sess.run(
        accuracy,
        feed_dict={features: test_features, labels: test_labels})
   
    

print('Test Accuracy: {}'.format(test_accuracy))
# Out:
# Extracting /datasets/ud730/mnist\train-images-idx3-ubyte.gz
# Extracting /datasets/ud730/mnist\train-labels-idx1-ubyte.gz
# Extracting /datasets/ud730/mnist\t10k-images-idx3-ubyte.gz
# Extracting /datasets/ud730/mnist\t10k-labels-idx1-ubyte.gz
# Epoch: 0    - Cost: 14.1     Valid Accuracy: 0.0876
# Epoch: 1    - Cost: 13.9     Valid Accuracy: 0.0868
# Epoch: 2    - Cost: 13.7     Valid Accuracy: 0.0864
# Epoch: 3    - Cost: 13.6     Valid Accuracy: 0.086
# Epoch: 4    - Cost: 13.4     Valid Accuracy: 0.0864
# Epoch: 5    - Cost: 13.3     Valid Accuracy: 0.087
# Epoch: 6    - Cost: 13.2     Valid Accuracy: 0.0874
# Epoch: 7    - Cost: 13.1     Valid Accuracy: 0.0878
# Epoch: 8    - Cost: 13.0     Valid Accuracy: 0.0876
# Epoch: 9    - Cost: 12.9     Valid Accuracy: 0.0884
# Epoch: 10   - Cost: 12.8     Valid Accuracy: 0.0896
# Epoch: 11   - Cost: 12.7     Valid Accuracy: 0.0898
# Epoch: 12   - Cost: 12.6     Valid Accuracy: 0.0914
# Epoch: 13   - Cost: 12.5     Valid Accuracy: 0.0918
# Epoch: 14   - Cost: 12.4     Valid Accuracy: 0.092
# Epoch: 15   - Cost: 12.3     Valid Accuracy: 0.0924
# Epoch: 16   - Cost: 12.2     Valid Accuracy: 0.0932
# Epoch: 17   - Cost: 12.2     Valid Accuracy: 0.0946
# Epoch: 18   - Cost: 12.1     Valid Accuracy: 0.0952
# Epoch: 19   - Cost: 12.0     Valid Accuracy: 0.0954
# Epoch: 20   - Cost: 12.0     Valid Accuracy: 0.0964
# Epoch: 21   - Cost: 11.9     Valid Accuracy: 0.0974
# Epoch: 22   - Cost: 11.8     Valid Accuracy: 0.0996
# Epoch: 23   - Cost: 11.8     Valid Accuracy: 0.1
# Epoch: 24   - Cost: 11.7     Valid Accuracy: 0.101
# Epoch: 25   - Cost: 11.6     Valid Accuracy: 0.102
# Epoch: 26   - Cost: 11.6     Valid Accuracy: 0.103
# Epoch: 27   - Cost: 11.5     Valid Accuracy: 0.105
# Epoch: 28   - Cost: 11.5     Valid Accuracy: 0.106
# Epoch: 29   - Cost: 11.4     Valid Accuracy: 0.106
# Epoch: 30   - Cost: 11.4     Valid Accuracy: 0.108
# Epoch: 31   - Cost: 11.3     Valid Accuracy: 0.11
# Epoch: 32   - Cost: 11.3     Valid Accuracy: 0.111
# Epoch: 33   - Cost: 11.2     Valid Accuracy: 0.113
# Epoch: 34   - Cost: 11.1     Valid Accuracy: 0.114
# Epoch: 35   - Cost: 11.1     Valid Accuracy: 0.115
# Epoch: 36   - Cost: 11.1     Valid Accuracy: 0.116
# Epoch: 37   - Cost: 11.0     Valid Accuracy: 0.116
# Epoch: 38   - Cost: 11.0     Valid Accuracy: 0.116
# Epoch: 39   - Cost: 10.9     Valid Accuracy: 0.116
# Epoch: 40   - Cost: 10.9     Valid Accuracy: 0.117
# Epoch: 41   - Cost: 10.8     Valid Accuracy: 0.118
# Epoch: 42   - Cost: 10.8     Valid Accuracy: 0.119
# Epoch: 43   - Cost: 10.7     Valid Accuracy: 0.121
# Epoch: 44   - Cost: 10.7     Valid Accuracy: 0.122
# Epoch: 45   - Cost: 10.6     Valid Accuracy: 0.123
# Epoch: 46   - Cost: 10.6     Valid Accuracy: 0.125
# Epoch: 47   - Cost: 10.5     Valid Accuracy: 0.125
# Epoch: 48   - Cost: 10.5     Valid Accuracy: 0.126
# Epoch: 49   - Cost: 10.5     Valid Accuracy: 0.127
# Epoch: 50   - Cost: 10.4     Valid Accuracy: 0.129
# Epoch: 51   - Cost: 10.4     Valid Accuracy: 0.13
# Epoch: 52   - Cost: 10.3     Valid Accuracy: 0.132
# Epoch: 53   - Cost: 10.3     Valid Accuracy: 0.133
# Epoch: 54   - Cost: 10.2     Valid Accuracy: 0.135
# Epoch: 55   - Cost: 10.2     Valid Accuracy: 0.135
# Epoch: 56   - Cost: 10.2     Valid Accuracy: 0.137
# Epoch: 57   - Cost: 10.1     Valid Accuracy: 0.138
# Epoch: 58   - Cost: 10.1     Valid Accuracy: 0.139
# Epoch: 59   - Cost: 10.0     Valid Accuracy: 0.141
# Epoch: 60   - Cost: 10.0     Valid Accuracy: 0.142
# Epoch: 61   - Cost: 9.96     Valid Accuracy: 0.144
# Epoch: 62   - Cost: 9.92     Valid Accuracy: 0.144
# Epoch: 63   - Cost: 9.88     Valid Accuracy: 0.146
# Epoch: 64   - Cost: 9.85     Valid Accuracy: 0.147
# Epoch: 65   - Cost: 9.81     Valid Accuracy: 0.149
# Epoch: 66   - Cost: 9.77     Valid Accuracy: 0.149
# Epoch: 67   - Cost: 9.73     Valid Accuracy: 0.15
# Epoch: 68   - Cost: 9.69     Valid Accuracy: 0.152
# Epoch: 69   - Cost: 9.65     Valid Accuracy: 0.153
# Epoch: 70   - Cost: 9.61     Valid Accuracy: 0.155
# Epoch: 71   - Cost: 9.58     Valid Accuracy: 0.155
# Epoch: 72   - Cost: 9.54     Valid Accuracy: 0.157
# Epoch: 73   - Cost: 9.5      Valid Accuracy: 0.159
# Epoch: 74   - Cost: 9.46     Valid Accuracy: 0.161
# Epoch: 75   - Cost: 9.43     Valid Accuracy: 0.162
# Epoch: 76   - Cost: 9.39     Valid Accuracy: 0.163
# Epoch: 77   - Cost: 9.35     Valid Accuracy: 0.165
# Epoch: 78   - Cost: 9.32     Valid Accuracy: 0.167
# Epoch: 79   - Cost: 9.28     Valid Accuracy: 0.169
# Epoch: 80   - Cost: 9.24     Valid Accuracy: 0.171
# Epoch: 81   - Cost: 9.21     Valid Accuracy: 0.173
# Epoch: 82   - Cost: 9.17     Valid Accuracy: 0.175
# Epoch: 83   - Cost: 9.14     Valid Accuracy: 0.175
# Epoch: 84   - Cost: 9.1      Valid Accuracy: 0.177
# Epoch: 85   - Cost: 9.06     Valid Accuracy: 0.18
# Epoch: 86   - Cost: 9.03     Valid Accuracy: 0.181
# Epoch: 87   - Cost: 8.99     Valid Accuracy: 0.183
# Epoch: 88   - Cost: 8.96     Valid Accuracy: 0.185
# Epoch: 89   - Cost: 8.93     Valid Accuracy: 0.187
# Epoch: 90   - Cost: 8.89     Valid Accuracy: 0.188
# Epoch: 91   - Cost: 8.86     Valid Accuracy: 0.19
# Epoch: 92   - Cost: 8.82     Valid Accuracy: 0.192
# Epoch: 93   - Cost: 8.79     Valid Accuracy: 0.193
# Epoch: 94   - Cost: 8.76     Valid Accuracy: 0.195
# Epoch: 95   - Cost: 8.72     Valid Accuracy: 0.197
# Epoch: 96   - Cost: 8.69     Valid Accuracy: 0.2
# Epoch: 97   - Cost: 8.66     Valid Accuracy: 0.203
# Epoch: 98   - Cost: 8.62     Valid Accuracy: 0.204
# Epoch: 99   - Cost: 8.59     Valid Accuracy: 0.207
# Epoch: 100  - Cost: 8.56     Valid Accuracy: 0.208
# Epoch: 101  - Cost: 8.52     Valid Accuracy: 0.21
# Epoch: 102  - Cost: 8.49     Valid Accuracy: 0.211
# Epoch: 103  - Cost: 8.46     Valid Accuracy: 0.213
# Epoch: 104  - Cost: 8.43     Valid Accuracy: 0.213
# Epoch: 105  - Cost: 8.4      Valid Accuracy: 0.214
# Epoch: 106  - Cost: 8.37     Valid Accuracy: 0.217
# Epoch: 107  - Cost: 8.33     Valid Accuracy: 0.217
# Epoch: 108  - Cost: 8.3      Valid Accuracy: 0.219
# Epoch: 109  - Cost: 8.27     Valid Accuracy: 0.22
# Epoch: 110  - Cost: 8.24     Valid Accuracy: 0.222
# Epoch: 111  - Cost: 8.21     Valid Accuracy: 0.224
# Epoch: 112  - Cost: 8.18     Valid Accuracy: 0.225
# Epoch: 113  - Cost: 8.15     Valid Accuracy: 0.228
# Epoch: 114  - Cost: 8.12     Valid Accuracy: 0.229
# Epoch: 115  - Cost: 8.09     Valid Accuracy: 0.232
# Epoch: 116  - Cost: 8.06     Valid Accuracy: 0.233
# Epoch: 117  - Cost: 8.03     Valid Accuracy: 0.235
# Epoch: 118  - Cost: 8.0      Valid Accuracy: 0.237
# Epoch: 119  - Cost: 7.97     Valid Accuracy: 0.239
# Epoch: 120  - Cost: 7.95     Valid Accuracy: 0.24
# Epoch: 121  - Cost: 7.92     Valid Accuracy: 0.242
# Epoch: 122  - Cost: 7.89     Valid Accuracy: 0.243
# Epoch: 123  - Cost: 7.86     Valid Accuracy: 0.244
# Epoch: 124  - Cost: 7.83     Valid Accuracy: 0.247
# Epoch: 125  - Cost: 7.8      Valid Accuracy: 0.249
# Epoch: 126  - Cost: 7.78     Valid Accuracy: 0.25
# Epoch: 127  - Cost: 7.75     Valid Accuracy: 0.252
# Epoch: 128  - Cost: 7.72     Valid Accuracy: 0.254
# Epoch: 129  - Cost: 7.69     Valid Accuracy: 0.256
# Epoch: 130  - Cost: 7.67     Valid Accuracy: 0.256
# Epoch: 131  - Cost: 7.64     Valid Accuracy: 0.259
# Epoch: 132  - Cost: 7.61     Valid Accuracy: 0.261
# Epoch: 133  - Cost: 7.59     Valid Accuracy: 0.264
# Epoch: 134  - Cost: 7.56     Valid Accuracy: 0.267
# Epoch: 135  - Cost: 7.53     Valid Accuracy: 0.268
# Epoch: 136  - Cost: 7.51     Valid Accuracy: 0.27
# Epoch: 137  - Cost: 7.48     Valid Accuracy: 0.273
# Epoch: 138  - Cost: 7.46     Valid Accuracy: 0.274
# Epoch: 139  - Cost: 7.43     Valid Accuracy: 0.277
# Epoch: 140  - Cost: 7.41     Valid Accuracy: 0.278
# Epoch: 141  - Cost: 7.38     Valid Accuracy: 0.28
# Epoch: 142  - Cost: 7.36     Valid Accuracy: 0.283
# Epoch: 143  - Cost: 7.33     Valid Accuracy: 0.284
# Epoch: 144  - Cost: 7.31     Valid Accuracy: 0.287
# Epoch: 145  - Cost: 7.28     Valid Accuracy: 0.288
# Epoch: 146  - Cost: 7.26     Valid Accuracy: 0.291
# Epoch: 147  - Cost: 7.23     Valid Accuracy: 0.292
# Epoch: 148  - Cost: 7.21     Valid Accuracy: 0.293
# Epoch: 149  - Cost: 7.19     Valid Accuracy: 0.295
# Epoch: 150  - Cost: 7.16     Valid Accuracy: 0.297
# Epoch: 151  - Cost: 7.14     Valid Accuracy: 0.299
# Epoch: 152  - Cost: 7.12     Valid Accuracy: 0.302
# Epoch: 153  - Cost: 7.09     Valid Accuracy: 0.303
# Epoch: 154  - Cost: 7.07     Valid Accuracy: 0.305
# Epoch: 155  - Cost: 7.05     Valid Accuracy: 0.307
# Epoch: 156  - Cost: 7.02     Valid Accuracy: 0.308
# Epoch: 157  - Cost: 7.0      Valid Accuracy: 0.309
# Epoch: 158  - Cost: 6.98     Valid Accuracy: 0.311
# Epoch: 159  - Cost: 6.96     Valid Accuracy: 0.311
# Epoch: 160  - Cost: 6.94     Valid Accuracy: 0.314
# Epoch: 161  - Cost: 6.91     Valid Accuracy: 0.316
# Epoch: 162  - Cost: 6.89     Valid Accuracy: 0.317
# Epoch: 163  - Cost: 6.87     Valid Accuracy: 0.319
# Epoch: 164  - Cost: 6.85     Valid Accuracy: 0.32
# Epoch: 165  - Cost: 6.83     Valid Accuracy: 0.323
# Epoch: 166  - Cost: 6.81     Valid Accuracy: 0.325
# Epoch: 167  - Cost: 6.79     Valid Accuracy: 0.326
# Epoch: 168  - Cost: 6.76     Valid Accuracy: 0.329
# Epoch: 169  - Cost: 6.74     Valid Accuracy: 0.33
# Epoch: 170  - Cost: 6.72     Valid Accuracy: 0.331
# Epoch: 171  - Cost: 6.7      Valid Accuracy: 0.333
# Epoch: 172  - Cost: 6.68     Valid Accuracy: 0.335
# Epoch: 173  - Cost: 6.66     Valid Accuracy: 0.337
# Epoch: 174  - Cost: 6.64     Valid Accuracy: 0.339
# Epoch: 175  - Cost: 6.62     Valid Accuracy: 0.341
# Epoch: 176  - Cost: 6.6      Valid Accuracy: 0.342
# Epoch: 177  - Cost: 6.58     Valid Accuracy: 0.344
# Epoch: 178  - Cost: 6.56     Valid Accuracy: 0.345
# Epoch: 179  - Cost: 6.54     Valid Accuracy: 0.347
# Epoch: 180  - Cost: 6.52     Valid Accuracy: 0.348
# Epoch: 181  - Cost: 6.51     Valid Accuracy: 0.35
# Epoch: 182  - Cost: 6.49     Valid Accuracy: 0.351
# Epoch: 183  - Cost: 6.47     Valid Accuracy: 0.352
# Epoch: 184  - Cost: 6.45     Valid Accuracy: 0.354
# Epoch: 185  - Cost: 6.43     Valid Accuracy: 0.355
# Epoch: 186  - Cost: 6.41     Valid Accuracy: 0.356
# Epoch: 187  - Cost: 6.39     Valid Accuracy: 0.357
# Epoch: 188  - Cost: 6.37     Valid Accuracy: 0.358
# Epoch: 189  - Cost: 6.36     Valid Accuracy: 0.358
# Epoch: 190  - Cost: 6.34     Valid Accuracy: 0.36
# Epoch: 191  - Cost: 6.32     Valid Accuracy: 0.362
# Epoch: 192  - Cost: 6.3      Valid Accuracy: 0.363
# Epoch: 193  - Cost: 6.29     Valid Accuracy: 0.364
# Epoch: 194  - Cost: 6.27     Valid Accuracy: 0.366
# Epoch: 195  - Cost: 6.25     Valid Accuracy: 0.367
# Epoch: 196  - Cost: 6.23     Valid Accuracy: 0.369
# Epoch: 197  - Cost: 6.22     Valid Accuracy: 0.371
# Epoch: 198  - Cost: 6.2      Valid Accuracy: 0.373
# Epoch: 199  - Cost: 6.18     Valid Accuracy: 0.374
# Test Accuracy: 0.3529999852180481
